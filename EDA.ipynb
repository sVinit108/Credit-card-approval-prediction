# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv('comp_dataset.csv')
comp_dataset = df.copy()
comp_dataset.drop(['index','ID'],axis='columns',inplace=True)
comp_dataset
# Out:
#       CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0               M            Y               Y             0
# 1               M            Y               Y             0
# 2               M            Y               Y             0
# 3               F            N               Y             0
# 4               F            N               Y             0
# ...           ...          ...             ...           ...
# 36451           M            Y               Y             0
# 36452           F            N               Y             0
# 36453           F            N               Y             0
# 36454           F            N               Y             0
# 36455           M            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0             427500.00               Working               Higher education
# 1             427500.00               Working               Higher education
# 2             112500.00               Working  Secondary / secondary special
# 3             270000.00  Commercial associate  Secondary / secondary special
# 4             270000.00  Commercial associate  Secondary / secondary special
# ...                 ...                   ...                            ...
# 36451         315000.00               Working  Secondary / secondary special
# 36452         157500.00  Commercial associate               Higher education
# 36453         157500.00             Pensioner               Higher education
# 36454         283500.00               Working  Secondary / secondary special
# 36455         112500.00               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0            Civil marriage   Rented apartment       33.00          12.00
# 1            Civil marriage   Rented apartment       33.00          12.00
# 2                   Married  House / apartment       59.00           3.00
# 3      Single / not married  House / apartment       52.00           8.00
# 4      Single / not married  House / apartment       52.00           8.00
# ...                     ...                ...         ...            ...
# 36451               Married  House / apartment       48.00           7.00
# 36452               Married  House / apartment       34.00           4.00
# 36453               Married  House / apartment       34.00           4.00
# 36454               Married  House / apartment       49.00           2.00
# 36455  Single / not married   Rented apartment       25.00           3.00
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0               1                1           0           0             NaN
# 1               1                1           0           0             NaN
# 2               1                0           0           0  Security staff
# 3               1                0           1           1     Sales staff
# 4               1                0           1           1     Sales staff
# ...           ...              ...         ...         ...             ...
# 36451           1                0           0           0        Managers
# 36452           1                0           1           1  Medicine staff
# 36453           1                0           1           1  Medicine staff
# 36454           1                0           0           0     Sales staff
# 36455           1                0           0           0        Laborers
#
#        CNT_FAM_MEMBERS  CREDIT_APPROVAL_STATUS  MONTHS_IN_BOOKS
# 0                    2                    1.00               16
# 1                    2                    1.00               15
# 2                    2                    1.00               30
# 3                    1                    1.00                5
# 4                    1                    1.00                5
# ...                ...                     ...              ...
# 36451                2                    1.00               12
# 36452                2                    1.00               24
# 36453                2                    1.00               33
# 36454                2                    1.00               10
# 36455                1                    1.00               14
#
# [36456 rows x 19 columns]

# %%
comp_dataset.describe(percentiles=[.10,.25,.50,.90])
# Out:
#        CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# count      36456.00          36456.00    36456.00       36456.00    36456.00
# mean           0.43         186683.45       43.78           6.04        1.00
# std            0.74         101789.69       11.52           6.49        0.00
# min            0.00          27000.00       21.00           0.00        1.00
# 10%            0.00          90000.00       29.00           0.00        1.00
# 25%            0.00         121500.00       34.00           1.00        1.00
# 50%            0.00         157500.00       43.00           4.00        1.00
# 90%            2.00         315000.00       60.00          15.00        1.00
# max           19.00        1575000.00       69.00          43.00        1.00
#
#        FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  \
# count         36456.00    36456.00    36456.00         36456.00
# mean              0.23        0.29        0.09             2.20
# std               0.42        0.46        0.29             0.91
# min               0.00        0.00        0.00             1.00
# 10%               0.00        0.00        0.00             1.00
# 25%               0.00        0.00        0.00             2.00
# 50%               0.00        0.00        0.00             2.00
# 90%               1.00        1.00        0.00             3.00
# max               1.00        1.00        1.00            20.00
#
#        CREDIT_APPROVAL_STATUS  MONTHS_IN_BOOKS
# count                36456.00         36456.00
# mean                     1.00            21.33
# std                      0.04            14.91
# min                      0.00             1.00
# 10%                      1.00             5.00
# 25%                      1.00             9.00
# 50%                      1.00            18.00
# 90%                      1.00            44.00
# max                      1.00            61.00

# %%
plt.figure(figsize=(7,7))
plt.boxplot(comp_dataset[['CNT_CHILDREN','CNT_FAM_MEMBERS']])
plt.yticks(np.arange(0,20,2))
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.boxplot(comp_dataset['AMT_INCOME_TOTAL'])
plt.yticks(np.arange(25000,2000000,100000))
plt.show()

# %%
isnull_sum = comp_dataset.isnull().sum()

num_vars = comp_dataset.select_dtypes(include=["int64", "float64"]).columns
num_vars_miss = [var for var in num_vars if isnull_sum[var]>0]

cat_vars = comp_dataset.select_dtypes(include=["object"]).columns
cat_vars_miss = [var for var in cat_vars if isnull_sum[var]>0]

# %%
plt.figure(figsize=(25,25),dpi=100, facecolor='white')
plotnumber = 1
for column in num_vars:
    ax = plt.subplot(5,4,plotnumber)
    sns.histplot(comp_dataset[column],kde=True)
    plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
# Seperating discrete value features & continous value features
# dis_val_feat = [column for column in num_vars if len(comp_dataset[column].unique())<=5] 
# cont_val_feat = [column for column in num_vars if len(comp_dataset[column].unique())>5]

# %%
plt.figure(figsize=(25,25),dpi=100, facecolor='white')
plotnumber = 1
for column in cat_vars:
    ax = plt.subplot(5,4,plotnumber)
    sns.histplot(comp_dataset[column],kde=True)
    plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(25,25),dpi=100, facecolor='white')
plotnumber = 1
for column in num_vars:
    ax = plt.subplot(5,4,plotnumber)
    sns.boxplot(data=comp_dataset[column])
    plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Meaning of Skewness
# # ![image-2.png](attachment:image-2.png)

# %%
comp_dataset.skew(numeric_only=True)
# Out:
# CNT_CHILDREN               2.57
# AMT_INCOME_TOTAL           2.74
# DAYS_BIRTH                 0.18
# DAYS_EMPLOYED              1.75
# FLAG_MOBIL                 0.00
# FLAG_WORK_PHONE            1.31
# FLAG_PHONE                 0.90
# FLAG_EMAIL                 2.87
# CNT_FAM_MEMBERS            1.30
# CREDIT_APPROVAL_STATUS   -26.95
# MONTHS_IN_BOOKS            0.73
# dtype: float64

# %%
unskewed_cols = [columns for columns in num_vars if ((comp_dataset[columns].skew())) > 1 | (comp_dataset[columns].skew()<-1)]
unskewed_cols
# Out:
# ['CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'DAYS_EMPLOYED',
#  'FLAG_WORK_PHONE',
#  'FLAG_EMAIL',
#  'CNT_FAM_MEMBERS']

# %%
for columns in unskewed_cols:
    comp_dataset[columns] = np.where(comp_dataset[columns]<comp_dataset[columns].quantile(.15),comp_dataset[columns].quantile(.15),comp_dataset[columns])
    comp_dataset[columns] = np.where(comp_dataset[columns]>comp_dataset[columns].quantile(.85),comp_dataset[columns].quantile(.85),comp_dataset[columns])
comp_dataset.skew(numeric_only=True)
# Out:
# CNT_CHILDREN               0.83
# AMT_INCOME_TOTAL           0.40
# DAYS_BIRTH                 0.18
# DAYS_EMPLOYED              0.39
# FLAG_MOBIL                 0.00
# FLAG_WORK_PHONE            1.31
# FLAG_PHONE                 0.90
# FLAG_EMAIL                 0.00
# CNT_FAM_MEMBERS           -0.10
# CREDIT_APPROVAL_STATUS   -26.95
# MONTHS_IN_BOOKS            0.73
# dtype: float64

# %%
comp_dataset.corr()
# Out:
#                         CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  \
# CNT_CHILDREN                    1.00              0.04       -0.39
# AMT_INCOME_TOTAL                0.04              1.00       -0.09
# DAYS_BIRTH                     -0.39             -0.09        1.00
# DAYS_EMPLOYED                   0.11              0.13       -0.15
# FLAG_MOBIL                       NaN               NaN         NaN
# FLAG_WORK_PHONE                 0.04             -0.04       -0.18
# FLAG_PHONE                     -0.02              0.00        0.03
# FLAG_EMAIL                       NaN               NaN         NaN
# CNT_FAM_MEMBERS                 0.79              0.02       -0.30
# CREDIT_APPROVAL_STATUS          0.00             -0.00       -0.00
# MONTHS_IN_BOOKS                -0.01              0.03        0.05
#
#                         DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# CNT_CHILDREN                     0.11         NaN             0.04
# AMT_INCOME_TOTAL                 0.13         NaN            -0.04
# DAYS_BIRTH                      -0.15         NaN            -0.18
# DAYS_EMPLOYED                    1.00         NaN             0.14
# FLAG_MOBIL                        NaN         NaN              NaN
# FLAG_WORK_PHONE                  0.14         NaN             1.00
# FLAG_PHONE                       0.04         NaN             0.31
# FLAG_EMAIL                        NaN         NaN              NaN
# CNT_FAM_MEMBERS                  0.12         NaN             0.06
# CREDIT_APPROVAL_STATUS           0.02         NaN             0.00
# MONTHS_IN_BOOKS                  0.08         NaN             0.02
#
#                         FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  \
# CNT_CHILDREN                 -0.02         NaN             0.79
# AMT_INCOME_TOTAL              0.00         NaN             0.02
# DAYS_BIRTH                    0.03         NaN            -0.30
# DAYS_EMPLOYED                 0.04         NaN             0.12
# FLAG_MOBIL                     NaN         NaN              NaN
# FLAG_WORK_PHONE               0.31         NaN             0.06
# FLAG_PHONE                    1.00         NaN            -0.00
# FLAG_EMAIL                     NaN         NaN              NaN
# CNT_FAM_MEMBERS              -0.00         NaN             1.00
# CREDIT_APPROVAL_STATUS       -0.01         NaN             0.00
# MONTHS_IN_BOOKS               0.02         NaN             0.02
#
#                         CREDIT_APPROVAL_STATUS  MONTHS_IN_BOOKS
# CNT_CHILDREN                              0.00            -0.01
# AMT_INCOME_TOTAL                         -0.00             0.03
# DAYS_BIRTH                               -0.00             0.05
# DAYS_EMPLOYED                             0.02             0.08
# FLAG_MOBIL                                 NaN              NaN
# FLAG_WORK_PHONE                           0.00             0.02
# FLAG_PHONE                               -0.01             0.02
# FLAG_EMAIL                                 NaN              NaN
# CNT_FAM_MEMBERS                           0.00             0.02
# CREDIT_APPROVAL_STATUS                    1.00            -0.01
# MONTHS_IN_BOOKS                          -0.01             1.00

# %%
plt.figure(figsize=(8,8),dpi=100)
sns.heatmap(data=comp_dataset.drop(['FLAG_EMAIL','FLAG_MOBIL'],axis='columns').corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
import dtale
import dtale.app as dtale_app

dtale_app.USE_COLAB = True 
dtale.show(pd.DataFrame(comp_dataset))
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Vinits-PC:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
